# %%
import numpy as np
import os
import glob
import keras as kr
import ryan_tools as rt
# Out:
# C:\Users\rfrancis\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
class TextGetter():
    def get_article_list(self):
        os.chdir('cleaned')
        file_list = glob.glob('*.txt')
        os.chdir('..')
        return file_list

    def get_article(self, name):
        os.chdir('cleaned')
        with open(name, 'r') as f:
            text = f.read()
        os.chdir('..')
        return text
    
    def get_corpus(self):
        articles = self.get_article_list()
        result = ''
        bar = rt.progress_bar(len(articles))
        for art_name in articles:
            result = result + self.get_article(art_name)
            bar.progress()
        return result

# %%
def get_text():
    text_getter = TextGetter()
    text = text_getter.get_corpus()
    return text

# %%
def create_dictionaries(text):
    char_id = dict(zip(set(text), range(len(set(text)))))
    id_char = dict(zip(char_id.values(), char_id.keys()))
    return id_char, char_id

# %%
def sample(a, temperature=1.0):
    a = a**(1/temperature)
    a_sum = a.sum()
    sample_temp = a/(a.sum()*1.0001)
    sampled = np.random.multinomial(1, sample_temp, 1)
    return np.argmax(sampled)

def convert_char_id(text):
    result = []
    features = len(char_id)
    for i, char in enumerate(text):
        position = int(char_id[char])
        observation = np.zeros(( features))
        observation[position] = 1
        result.append(observation)
    return np.array(result)

def convert_id_char(onehot, temperature):
    result = ''
    for letter in onehot:
        l = sample(letter, temperature)
        result = result + id_char[l]
    return result

def get_X_y(list_of_one_hots, sentence_length, do_bar = True):
    y = []
    X = []
    if do_bar:
        bar = rt.progress_bar(len(list_of_one_hots), 100)
    for i, letter in enumerate(list_of_one_hots):
        if i > sentence_length:
            y.append(letter)

            x = list_of_one_hots[i- sentence_length:i]
            X.append(x)
        if do_bar:
            bar.progress()

    return np.array(X), np.array(y)

# %%
def generate_model(X, y):
    model = kr.models.Sequential()
    model.add(kr.layers.LSTM(128, input_shape=X.shape[1:],return_sequences= False ))
    model.add(kr.layers.Dense(X.shape[2]))
    model.add(kr.layers.Activation('softmax'))
    optimizer = kr.optimizers.Adam()
    model.compile(loss='categorical_crossentropy', optimizer=optimizer)
    return model
model = None

# %%
def predict(text, temperature):
    onehot = convert_char_id(text[-sentence_length:])
    return convert_id_char(model.predict(np.array([onehot]), 1), temperature)

# %%
def print_letters(seed_text, sentence_length, how_many, temperature= 1):
    while len(seed_text) < sentence_length:
        seed_text = ' ' + seed_text
        
    result = seed_text
    for num in range(0, how_many):
        prediction = predict(seed_text, temperature)
        seed_text = seed_text[1:] + prediction
        result = result + prediction
    return result

# %%
text = get_text()
id_char, char_id = create_dictionaries(text)
one_hots = convert_char_id(text)
# Out:
# 0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o> | 100.00 %
# Done: 324 Remaining: 1, Remaining Time: 0s

# %%
sentence_length = 100
X,y  = get_X_y(one_hots[0: 1000], sentence_length)
model = generate_model(X, y)
# Out:
# 0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0o0>          | 90.09 %
# Done: 900 Remaining: 100, Remaining Time: 0s

# %%
import time

# %%
def test_sizes(batch_size, samples, epochs):
    global start_point
    start = time.time()
    X,y  = get_X_y(one_hots[start_point: start_point + samples], sentence_length, False)
    callback = model.fit(X, y, epochs = epochs, batch_size= size, verbose =0 )
    start_point = start_point + samples
    time_taken = time.time() - start
    print(start_point)
    print('Projected Time for 10000 samples {}'.format(time_taken * 10000/(samples* epochs)))
    return callback

# %%
len('The five whys analysis is also known as the why-why chart and root cause analysis.')
# Out:
# 82

# %%
for num in range(start_point, len(one_hots)):
    if num%160 == 0:
        start = num
        
        callback = test_sizes(160, 160, 100)
        print(min(callback.history['loss']))
        for temperature in [0.1, 0.3, .5, .7, 1]:
            print(temperature)
            seed_text = 'The five whys analysis is also known as the why-why chart and root cause analysis.'.lower()
            print(print_letters(seed_text, sentence_length, 100, temperature).capitalize()[len(seed_text):])
        if num%10000 == 0:
            rt.clear_output()
# Out:
# 5720
# Projected Time for 10000 samples 7.159374803304672
# 0.6902888417243958
# 0.1
# ot cause analysis.mamis sefodededed apedened rer alenmenm-salormins rerker preror mergr prors mer ris rer wer alminm-s
# 0.3
# ot cause analysis.mas as alaminm-sfrorkers erer aemenmers as alkers arseder penf ror ring as am rers rers per aomenys
# 0.5
# ot cause analysis.m-ald alminds aek areod mer r rorkers-menmacs amir rs-for wer pror ror rers-sprros mer rerks-forfoa
# 0.7
# ot cause analysis. ad alks-faomed ars lanmener prasks aorfordenssamer rd a> peror anmrrs ress ae reovernst rinsma>enma
# 1
# ot cause analysis.smeincmanes-.ffeore mins rer pr-yomocyrony-mmarkirr-clomennryrss her har doopwrfepr er rhhgp-fomonmr
# 5880
# Projected Time for 10000 samples 7.303125113248825
# 0.7517054080963135
# 0.1
# ot cause analysis.tad aer teren 201 then 201 wan 2011 wend 2011 when s ayuts ratrructrrutrrutrr tarirs tractrrac ay cc
# 0.3
# ot cause analysis.tatin rs aewer 2011 ween 201 whenk 201 and 201 and rs ay trructrrstrrutarurs taterwet r2011 2e1 wee
# 0.5
# ot cause analysis.taber teruned terte wee 201 wheng 2015 wend 2010 2001 wen d russ arsurstkury taccrars rractrralicend
# 0.7
# ot cause analysis.tett ied 201111 200 wenn 2r wgand 0wy dend 201 2h0n a0 2yud 2r teuny rstuyylytr tictran rrrs aallucl
# 1
# ot cause analysis./2etgeg hen d20 fha 10 1dwen 201 k210105nyery surstrubctrrics ratcrrgnrs atiut rer 2011 hen5  2011ww
# 6040
# Projected Time for 10000 samples 7.193749845027924
# 0.703062117099762
# 0.1
# ot cause analysis., ta then tong pras hant and ant rons rans ran shen the then tong pras haf tan ins rans, res hefte a
# 0.3
# ot cause analysis., at an ins pent and anthint ant rons ant and in-shint on then thin than ting pras onf and int ont i
# 0.5
# ot cause analysis.tan tin ton shint hint en ins on sexa tians oat in- han the the atanins, ta this ton tains in-mint e
# 0.7
# ot cause analysis., int en-shint on shen than  hac, amines pres hen thift on ,ind ress tan taf ins sar pr-shins iotefo
# 1
# ot cause analysis.et et- an ris hrns ind ort-/printhoft-profforate,intries int hin ,on din tan tans gr-hhet antiaboese
# 6200
# Projected Time for 10000 samples 7.093749940395355
# 0.5888808369636536
# 0.1
# ot cause analysis. teng <ant res seciing resta berkes bentra bers se tore sta shent acting tat rese atin sere ta berse
# 0.3
# ot cause analysis. teng <hen  es accinesst/e><>, <p>thee sticcinesses then  acti cinesssete aha ta tcackinesssebera ta
# 0.5
# ot cause analysis. ong ra ta cicesessethe ath at  acciiinssers hen <he a actoress besera ara ta torisents baar a strii
# 0.7
# ot cause analysis. theg ta ccerminess bera ar taltoinesgre/h3>, <p>thees meccontoness beran  arcliemtrr-serecarassr be
# 1
# ot cause analysis. pnge,n t bbancinteisth3>, 3<hp>t ge<p>, stant it icdgrse/<h/h3>, <p>germkentie<ntegg<p>thesm takk m
# 6360
# Projected Time for 10000 samples 7.360000014305115
# 0.8030318021774292
# 0.1
# ot cause analysis. ane ace surend rer ane surper and or under ures ore cand or pane ser pane suren ser ane sure tar on
# 0.3
# ot cause analysis. ata or or underg ore tave und pre tar oun inderg and an  anes ured an cor under seracce, round ring
# 0.5
# ot cause analysis.>, af acou urunderground mine cor ond unden sora acever per pracer ound porf ane s ine tor spre emea
# 0.7
# ot cause analysis., ta fac er ingererinppre tar aceur ring or eas oruunder upher tanf fo s und re tor mine csere tar i
# 1
# ot cause analysis. ha tave ie .rdep>, are, or inun. trne tac serg ing pan  afkoruusdruepar prane, orf ace,  ind pre .e
# 6520
# Projected Time for 10000 samples 7.143750041723251
# 0.5100117921829224
# 0.1
# ot cause analysis. fake e oy or coyerond corer out orkeng fond one, on shoy sake, enal ackey pho lald keeg out seyer s
# 0.3
# ot cause analysis. fake e or oye yes arkeround pone farken ey poy or shor chenges oye shof rake peng one shor shoy cor
# 0.5
# ot cause analysis. facke, er oy oyes ard aekeng ond foew cake, on soye sha lakee pey for ceyeng heg serfald cor coyeye
# 0.7
# ot cause analysis. fak ce ep, ond on acor the war soiedey soy srooys forton mpehey oul for ackerod ond ker oudd conde
# 1
# ot cause analysis. fawh ke kony ymyer omhyecker inge coreageryelde elcluring foykoy uy lor siak plouyeye  thoperging,
# 6680
# Projected Time for 10000 samples 6.814374923706055
# 0.4179757237434387
# 0.1
# ot cause analysis. chert accorane rofland cortrof ccinenr orland ne lor accorine corind coontr foracceine corand coond
# 0.3
# ot cause analysis. n ertrof lan, er rofaccingin <accrore="h eppror acheef="he ent roof aceenine corfance wint <o <pree
# 0.5
# ot cause analysis. cher racondine ccorpranccine cor alh refanheind cocprre accarorer acconnrr oolt pchane ccarinpee <a
# 0.7
# ot cause analysis. <p, <in  r sarhalein rroond cor pracorichcoand an an corane evonth fo ta canine r<alcor int conein
# 1
# ot cause analysis.=" her shor achen plin <h phof fweneed inn sof on  linerc wanver oil ac cinan cood phe andislon , rl
# 6840
# Projected Time for 10000 samples 6.728750020265579
# 0.5481575727462769
# 0.1
# ot cause analysis.2fsaptrr+%2fsectport+75.221&part+7ssscactir+ess+u221&art+7522fsubpactirtersi%2fpart+75%2fsubtcort+72
# 0.3
# ot cause analysis.2fsaptersi%2fsaction+75522fpar+75.2fsucthort+75%2fsuptar+i%2fsubtactir+75ssubchartessubpactro++7522f
# 0.5
# ot cause analysis.22fpinte+s=%2fhactir+%22fsucthont+7fsbbcpart++522fsubtipprrssbcppart++%%2fsuattir+75221&tppre.t2fpec
# 0.7
# ot cause analysis.2feptart+%2fsectaopt+75.22fpsac.estsractact+o221572fte7t+u22ffactirte522f2bhar+75.2fsubtar+i%2fsufcp
# 1
# ot cause analysis.22&2ppheatseustobha%teeb.ptheatseudfopfsbfboiters72212bc+int+rsubcactir+ucts=5pr+ans+.ithers+tactan7
# 7000
# Projected Time for 10000 samples 6.760624945163727
# 0.6621846556663513
# 0.1
# ot cause analysis.<</>, <p>goccssese=fkekke22155.25.221221&a" ss="arke"75"221 te kes.u2frre75.2221&art"u"ubark755"2211
# 0.3
# ot cause analysis.</>, <p>gest==l=kke5keu2fsublanke"sf=fbke"5"t="">bl p>gactro75.">< ror ingroublowtarke"5="_brke"5"ar
# 0.5
# ot cause analysis. <far ms="_bro"womp="rebrouttref orfbrow"rte" ming rforkomp;f rorkont">3r cort 75.2r emp;rroomwarter
# 0.7
# ot cause analysis.<0 <a>, mshrro=blowka552f="_blond"matr mu"tark""">t=" prengeftcwro"n p20 2ft7k"""umt=rke sublarketg3
# 1
# ot cause analysis. <ha  emt==_brkw"mg <0a/tu/.="arrk75.="rse/ 2r>e cls7ag2>ersupaar="t2tfromwt>0rfombuacter+i"ne<, raf
# 7160
# Projected Time for 10000 samples 6.733125001192093
# 0.4647656977176666
# 0.1
# ot cause analysis.</p>, <p>slips and fall ar af aman mane mongemhine ming md al ding <h3>, <p>sips and fall ar amhand
# 0.3
# ot cause analysis.</p>, <p>slin sasl alal ar ase ald ale mine <h3>, <p>slips and saflall are amdond the mast omlly <h3
# 0.5
# ot cause analysis.</p>, <p>slips and alal res all ong hhes man mine</h33>, <p>lsips aals all alh al an mont mone d th>
# 0.7
# ot cause analysis.</ p><p>slaps and falla  are alond add adl mhhi3s<i>>liss ars anl ame flond the</h3>, <p>s and falls
# 1
# ot cause analysis.</p>, <p>>sian aatmfas er are mats hreyysca lomg hel//l3><ep>dipsefs alfs aal a72far cyante horety m
# 7320
# Projected Time for 10000 samples 6.722500026226044
# 0.9536586403846741
# 0.1
# ot cause analysis. fare the tor improf ros fale the tor improf tes fare the tor improf ros fall ite fare tor improf ro
# 0.3
# ot cause analysis. fre tor improf ros fare the frol improf te for improf rof fall imeroul mimerol imestere frol imesto
# 0.5
# ot cause analysis. fre tor improf am tof rof ol omprferom faros the for imtrof imest ee fart mijprof rose fare the far
# 0.7
# ot cause analysis. frel mpreulor sterer allvome fare mprore taje ihfzfare stars falom th oroutt omertumes are mpare mp
# 1
# ot cause analysis. famtij ompar ise fala utelflyes rot of tpse mroe  arg apote ors mpre of rosuttes orv thof impeof fr
# 7480
# Projected Time for 10000 samples 6.924999952316284
# 0.687984049320221
# 0.1
# ot cause analysis. tof and ane ofe tof ine of fall protective use of fall protection; in seet rof and toe tand it roe
# 0.3
# ot cause analysis. eff and ife als if eckise tane tacl ite ot avs an se als ite oft of ite of fal ins efe tof ate of t
# 0.5
# ot cause analysis. tof and tore als ine of cais rone tiee fafl ipe teetor ine toef ate oal int eectio ;i e seckes and
# 0.7
# ot cause analysis. te oartine useese fafl it ofeeks ffe etive ase fale fape terose tos eas ot eras at rof it of tre or
# 1
# ot cause analysis. preesaswiid uall proective ;ake ff ke farclin; tehe it acpait ond pif eat is ron;uif se tse fs ttou
# 7640
# Projected Time for 10000 samples 7.160000056028366
# 0.35808834433555603
# 0.1
# ot cause analysis., <h3>expand one anfing and ane sane ;and more sanes and more sang ane sane sane sane sanes and more
# 0.3
# ot cause analysis., <h3>expand inecoffind dngeced ine ang ane, sane more sane ;and more sanes; and mare sanes and more
# 0.5
# ot cause analysis., <h3>expand ineconfind nnes;and in cand ane s ane ;o andin. <h, <h3>esploding ang and ;anes and san
# 0.7
# ot cause analysis.</h3>></a>p oppiped ing on. ane, eacd anes;ang ofe anduin </p>, <hp>exs dind and monduses and ars an
# 1
# ot cause analysis., <hp>exlhing condind nnn., andd hveecon. pane;s angd</>e, <h3>excivd inns;anding son mine, an seand
# 7800
# Projected Time for 10000 samples 6.779999881982803
# 0.3335992395877838
# 0.1
# ot cause analysis.</h <h3><psadepplonkiigesthiza al arg arg ane ar-sha hazpre="l ar ares-haza t-ar ar--hagg ag tare s
# 0.3
# ot cause analysis.</h <h3p>dtoptockanging-hazhi"e s ar ade-s are ar-s ar iag th hazt are por hagh "> ar pach pro hes l
# 0.5
# ot cause analysis. hazataed por aad sh hazd pfally ho hapd ar aro-h hagh "hes ar sarg ag th h=">t pshacles- or iad er
# 0.7
# ot cause analysis.<p> <amptoredpshashi"l slazaro d-roghi""-slladl as roze t ar ise cazart -omire-s-hig s <h plld="fos
# 1
# ot cause analysis.<h <apl pfcicly haza de/fazthazt azlapys hazardec0par arg"rhpha l st<ocy routly ho ark to hhash s=hp
# 7960
# Projected Time for 10000 samples 6.77375003695488
# 0.25494635105133057
# 0.1
# ot cause analysis. px&adth="207"220px&wwtht7"20p202777px" width="207" t-mpalling.jhg?width=207px&amp;height=20px&amp;h
# 0.3
# ot cause analysis. px&adtheg.jpg?width=207px" width="hipg wadting.jpg?width=27ipg-mp;heig.jpg?width=207px" wthed.jpg?w
# 0.5
# ot cause analysis. ppowtidg7"20px&watt-;hight="expadding-hont-=thimp;-futhgight="207px&amp;hiig-ht?<pp?width="idi"gt="
# 0.7
# ot cause analysis.7ip2 pxwiid he0277"px" width="27" t="2pawtimp;h=p0ot="xmpxtiight=2027" pm&pploiding.jhg?</pxaliigh="
# 1
# ot cause analysis. pxmiath-2phhpp>kewthidg."th=2072px&id.jhp;oming.=th7".jpxhinghth-hidg<p>r pipdanding20077.px" wipth
# 8120
# Projected Time for 10000 samples 6.746875047683716
# 0.19370809197425842
# 0.1
# ot cause analysis. <he>e wand ines:</p>, <p>aceikellling bewwer 201 and mines:wwtees <0a>e <p>eaclinline forte a kerke
# 0.3
# ot cause analysis. <p>eaclind bewwend be wind 2011 and mines:wwthee</p>e aplkealling were an feres anhexkel fines <01>
# 0.5
# ot cause analysis.</p>e <and amekelled foveen f blwene weran mine weale al weal dine wafe dand be feel in weekkent ace
# 0.7
# ot cause analysis.e fh alled fhevlein thenter skiveswerees bertee w illed 20111 pe  wvenl 2011</20021 kak memhes rone
# 1
# ot cause analysis. <hexweed 2fered ne bedvere 20 andhne he2bent:he<>2 p> afkemeell ine wowed ve owmind 2f wwenke ks we
# 8280
# Projected Time for 10000 samples 6.733125150203705
# 0.29557719826698303
# 0.1
# ot cause analysis. ta e, flyrock, the seany grest re ally aress ble the proas tores saro, plyere, flyrock, preany gfse
# 0.3
# ot cause analysis. ta an, blyront on bly are, tyront be tlyron ses ar rsers sero a, flyroas ro thes ales bly thene asl
# 0.5
# ot cause analysis. tre eblyyrocs tore, flyyrock tore s anes fontyyrgayystheslyyiny jont s p>e an, flstsen s flyyrorkse
# 0.7
# ot cause analysis.lta e' flyrock, prean u flserare,styyrocks blen' flort cein jes tary blyyroasls poreny sestan s, fya
# 1
# ot cause analysis. torje_s</pr ajess bly aly ror'ys 0le skara msesty beset lyejgkent anest rigesfly bjbsys bles fyrry
# 8440
# Projected Time for 10000 samples 6.728125065565109
# 0.39461615681648254
# 0.1
# ot cause analysis. araseffrortiotrory prosiots eapresprotict ont an pefterigreresros protecont ont en presireserator p
# 0.3
# ot cause analysis. araseffcatror ersiontory proseiction can guatd raase ffortior cary roat aresringeres arseestove pro
# 0.5
# ot cause analysis. arase friatre prostecyioa cfant erpacesprosina cfurtigerad proctivese riprotint on pivester proesti
# 0.7
# ot cause analysis. aras, prationtrocprorsiontuctive pfiostor presporiins card efecliprorsive crintroactuve casive ples
# 1
# ot cause analysis. pareepfcatrioreersioprovevontyrorpespciteocting, and peffestirg ctivectin preeprorotriontion gere p
# 8600
# Projected Time for 10000 samples 6.748124957084656
# 0.37780699133872986
# 0.1
# ot cause analysis. an mesetan mentey in meath yeras menthe tacen manes mines eath eracs mines eath erals on res ron me
# 0.3
# ot cause analysis. an metan ron meatly in metal/nonmetal mines in recent coar memplonent cana memploners can metal/nn
# 0.5
# ot cause analysis. an mines an sean in minas. employ res ceans cearles mentsy in memetsecan meatl yerat cine meath ne
# 0.7
# ot cause analysis. an menes an meas en thy ars. cpanmins canan m eass on the ullnyerseny can con mins. mines yints eat
# 1
# ot cause analysis. an manes in leaten mines emtas minm emeeston lan memployers ceartcyite metal/yno merll mintsonins-m
# 8760
# Projected Time for 10000 samples 6.69562503695488
# 0.4564448297023773
# 0.1
# ot cause analysis. theckiastic prestin pleatr cint ceat seat al inesect anes an mins chesklitas mins chat mayersect an
# 0.3
# ot cause analysis. th plationtuct an peclins chetklyit mectacling cheatl ars blits card blitasect cat an prection chec
# 0.5
# ot cause analysis. the clayins meatlyerts an cleyines, at cuins chat ly ins.ctar minesecin mears int ceatr chins itack
# 0.7
# ot cause analysis. ch allyicts, in ple ins bes uhes litactuit cthan muccreating inesecy als cas ceatuceat s, and minpu
# 1
# ot cause analysis. ces alysand ch ploatd bing>, ars.tig slessic tuckhint ureckeiyets orpsu at clitses to5 mitesuite tu
# 8920
# Projected Time for 10000 samples 6.71812504529953
# 0.37595507502555847
# 0.1
# ot cause analysis. tampecluroves to arou tus arese tuseroves tou ruses ios unes afesuctio tur acluios foacdes s and an
# 0.3
# ot cause analysis. tampecluroves to curoves recetiove trove ans ires tuior mesactur cuatas nu ralesoves am ures ines i
# 0.5
# ot cause analysis. tompucluars tom cale presict our cesor ceut ure ard in sures ad in suroves iy provess etackin s too
# 0.7
# ot cause analysis. pamepeseo ames af ioc roves its ures ctovu nmes aney cfeard be us ar ctour ane mines ars. ans prave
# 1
# ot cause analysis. emplcetyove is prouts en ucleat  maudeve aca, ars vo ames roveus esuveses ceutov es ceeerunds e day
# 9080
# Projected Time for 10000 samples 6.8287500739097595
# 0.27915167808532715
# 0.1
# ot cause analysis. th inguines in peoting and emines in ine montout indiniguid inesino thisprovimest improning inemelt
# 0.3
# ot cause analysis. th inguinemeto t on mesesin meide ton minemines in touimproves tiiong</a>. thinu giingu</p> peation
# 0.5
# ot cause analysis.</ta umpiminesecto tiongutime thing ine peleiov thi gutid guinde to imines iom thimgroninmpomectove
# 0.7
# ot cause analysis. thi gundinestic mond ines in ghimemethi gnoniming iufesti  guinde tio menoctes im mines th ioniding
# 1
# ot cause analysis., is imuromine the continug netoallinmores und in choingultoc nifu nlinhsthes cunand thuctouim proet
# 9240
# Projected Time for 10000 samples 6.791875064373016
# 0.19857418537139893
# 0.1
# ot cause analysis. thushout all provestot choguthe klod resin mhes ho sriogrout meides ofes lo srove mhid sho proutid
# 0.3
# ot cause analysis. thi gho thel allis ros it goot mefl iozs <has.<//p>, <h3>, aleded this ho tig res.</p>.</h3>>.lades
# 0.5
# ot cause analysis.rteuro to proves af s lopsofet outiges th piog ond hreethos in ship>.</p>re tiid gres to proumid she
# 0.7
# ot cause analysis. oudele th ous chprouto th ond ize tl prosestllish ghon mhes th ihg tos ghethes to thoughof role id
# 1
# ot cause analysis.<//th <hht hrider mises.</hp>.,<h3>lerled or. hesp/onthou im the kot zhe /ide rofet koustks shmoud c
# 9400
# Projected Time for 10000 samples 6.773124933242798
# 0.18059617280960083
# 0.1
# ot cause analysis. ahes mind-eas-hesidest ind"ht sins></2min>s"</s>>]sismems cllspiofectlosin-sest--hin-"estll in-fect
# 0.3
# ot cause analysis. ahes mind-eat-hestines tes ineses ticsminme"efes "-leadls</s22>[<h1>]</s>ss</11>][</1 all aresestsa
# 0.5
# ot cause analysis. ales mineseata[he tiongeas-hes mices-he22-hest"></p>-h</s>><</sla>d lllsco>s<//>>, <h>][llecs alss=
# 0.7
# ot cause analysis.<=22>]</11 teresl</ssa="><</mallfs="2isg-head-lesi"></>2h1]<h>t>]</s>>
# </2>][<hs all>
# </h>[<hst1 cle
# 1
# ot cause analysis.<=a><</malass/a></hrestcess </spra"</s><
# <hssh=2>etolct ors=">lesh>
# </3>]]</dmerll sas/sict-</san-he
# 9560
# Projected Time for 10000 samples 6.76624983549118
# 0.256037175655365
# 0.1
# ot cause analysis. wesping wis roves ingrovimg werker ilg orig wesker worker ilesion ghesping wesprovimging"><img wesk
# 0.3
# ot cause analysis. wesping wils orsive imgrove-king"><irg wesking werkerongive-img"><img ant="oil rig worker werispros
# 0.5
# ot cause analysis. wespons wis rons weskerk reotion workeron-reotong"><img al imes rles wess orimerin "lorimg werseve
# 0.7
# ot cause analysis. werepi= sels ong clarkg werker wive-pond werimprocsives alemiog weskeresiviggrovimg als corkerke</p
# 1
# ot cause analysis.g"iter w-lmerl wolsp>s colire" worke ragecesping</aing="<i>s wessivl ghocke r-iver plovimprig<ig1 re
# 9720
# Projected Time for 10000 samples 6.910624951124191
# 0.13595883548259735
# 0.1
# ot cause analysis.<//ha><//>watpalers in tho-eres the-heaspre-heat ron-heas.</p>, </p>atspresion ton header1.jpg"/></s
# 0.3
# ot cause analysis.<//ha><//>warkerses prewerkery inestandigg</>><//ha></p>aspans res in thae-ser thg"i></spa></p>, tpp
# 0.5
# ot cause analysis.<//har></a>, an-areales.jpg"/wo>erspre-sion tha-heres.jpgw"></spro></p>,e<p>ion ton-ealars.jpg"/a>es
# 0.7
# ot cause analysis.were.j1g/w></sp>, <p>workers in thagej/s rpa></als rpaasery jow reto-he-slpwestoy the -latsin> he-fp
# 1
# ot cause analysis.</p>,a</>are.11="><haker1"i/>, hewia/rag-oavery-read 11prag</>><p>, </p>atslan to crerkes top-gawil-
# 9880
# Projected Time for 10000 samples 6.7368751764297485
# 0.15937720239162445
# 0.1
# ot cause analysis. on coat an to ale jou the job compred to reas arteo tines on the ond to ale to the ale the reutin t
# 0.3
# ot cause analysis. on toathe <h omale jod tol ales thes on torered bimpres on tor ad to the on ties and arpas the thou
# 0.5
# ot cause analysis. on cha he jouthe jon compres on the job compered to all other industries in the unites on toa the s
# 0.7
# ot cause analysis. jou mine obl the job compared to the thouthersin timeroud ires ob coralerjon coheteous top eol thea
# 1
# ot cause analysis. od coat ans ortau >t athe  oi the johurthe tb umt ere on ther5gout claseod cetrinesout the im custh
# 10040
# Projected Time for 10000 samples 6.747500002384186
# 0.30997300148010254
# 0.1
# ot cause analysis. ghe ming are conthe jon con aled al the iinding in ald thes in the ciin gal in ald alt antin in tin
# 0.3
# ot cause analysis. en mingered in the cin tre tion ind al an thes ininguon in gextas intin in tin exd athe clin tom il
# 0.5
# ot cause analysis. gemuacp ardextis industin ind gout he jlis in mines an to the cil timeminin gou tan ald sila se cin
# 0.7
# ot cause analysis. ggou chead elts anlinguot in deats an duss, atid gion ines ches all tac mithe siin gin the dlantin
# 1
# ot cause analysis. ged ineat ection inles in the soin he tle tilanisg in ste llint gou inu all minseactio tho in ind c
# 10200
# Projected Time for 10000 samples 6.727499961853027
# 0.3511650264263153
# 0.1
# ot cause analysis.estiontocciod.codes/213112/support-activities-for-oil-acle-siod-sor-anicom/es/21iced//sescodeustii-t
# 0.3
# ot cause analysis.estio-ion-for-al-sor-es/ioc-oal..com/es/21312/211pactav/idestor-ionico-al/131112/suppor-activities/f
# 0.5
# ot cause analysis.ectroiitin-ales-iod./21311/21/ppant-activitis/2odu/or-eats/inides/or-fiod-for-ios-oamer-el/siot-acti
# 0.7
# ot cause analysis.esticiincofes-or-es/cotivectovicodes/fie-somies-oflofcom-es--aestomiines-oom-ain-soade.cod/es/21-ict
# 1
# ot cause analysis./sit-fio--oama.j/r-foidion-des/2e 2ortil1cines/foct-acii-gocae.cok/es/iilsind-act-</eac.</po/2-fesio
